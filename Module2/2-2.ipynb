# %%
x = 10
print(x)


# ctrl + SHIFT + B VSCODE當機重啟
# ctrl + SHIFT + p 命令列
# Ctrl + Enter 執行cell
# 往上新增 cell -> A 
# 往下新增 cell -> B
# 跳出cell -> Esc
# 刪除cell -> X
# Out:
# 10

# %%
# VS code 功能
# 複製單行程式碼 => alt + Shift + 上下鍵↑↓

# %%
# shift +space 符號轉全形
# |上下鍵
