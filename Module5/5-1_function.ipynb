# %%
print('Hello World!')

# %%
# 建立 function 1
def greeting():
    print('Hello World!')
x = greeting()
greeting()
greeting()

print(x)
# Out:
# Hello World!
# Hello World!
# Hello World!
# None

# %%
# 建立 function 2
def greeting():
    msg = 'Hello World!'
    str_list = msg.split()
    return str_list

x = greeting()
print(x)

print('程式結束')
# Out:
# ['Hello', 'World!']
# 程式結束

# %%
# 建立 function 3
def greeting(msg, name):
    str_list = msg.split()
    str_list.append(name)

    return str_list

data = greeting('Hello World!', 'andy')
print(data)

data = greeting( name = 'andy',msg = 'Hello World!')
print(data)
# Out:
# ['Hello', 'World!', 'andy']
# ['Hello', 'World!', 'andy']

# %%
# def get_msg_list
# Out:
#   Cell In[6], line 1
#     def get_msg_list
#                     ^
# SyntaxError: expected '('

# %%
# 建立 function 4
# 預設參數值
def greeting(name, msg='good morning'):
    str_list = msg.split()
    str_list.append(name)
    return str_list

data = greeting('user')
print(data)
data = greeting('user','Hello World!')
print(data)
# Out:
# ['good', 'morning', 'user']
# ['Hello', 'World!', 'user']

# %%
# 建立 function 4
# 預設參數值
def greeting(name , msg='good morning') :
    str_list = msg.split()
    str_list.append(name)
    return str_list

data = greeting('user')
print(data)
data = greeting('user','Hello World!')
print(data)

# %% [markdown]
# -----

# %%
def remove_list_odd_num(num_list):
# Out:
#   Cell In[24], line 2
#     def remove_list_odd_num(num_list):
#                                       ^
# _IncompleteInputError: incomplete input

# %%
def add_nums(*args, **kwargs):
    print(args)
    print(kwargs)
    sum = 0
    for i in args:
        sum += i

    for key, value in kwargs.items():
        sum += value

    return sum

add_nums(1, 2, 3, 4, 5, n1=100, n2=200)
# Out:
# (1, 2, 3, 4, 5)
# {'n1': 100, 'n2': 200}
# 315

# %%
# 改寫 Module2 practice

def get_discount(total,discount):

        if total >= 2000:
    # cnt = total // 2000
    # total -= discount * cnt
            total -= discount * (total//2000)
        return total

data = [
      {
            'total': 6000,
            'discount':200
      },
      {
            'total': 8000,
            'discount':200
      }
]
for d in data:
    #   print(d["total"], d["discount"])
      answer = get_discount(d["total"],d["discount"])
      print(f"折扣後的金額: {answer}元")

# d1 = get_discount(8000,200)
# print(d1)
# Out:
# 折扣後的金額: 5400元
# 折扣後的金額: 7200元
