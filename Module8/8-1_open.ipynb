# %% [markdown]
# ##### `open()` 函式
# |`"r"`|`"a"`|`"w"`|`"x"`|`"t"`|`"b"`|
# |:--:|:--:|:--:|:--:|:--:|:--:|
# |read|append|write|create|text|binary|

# %% [markdown]
# ##### 讀取檔案 read( )

# %% [markdown]
# encoding='utf-8'
# 有中文字，解碼

# %%
# 印出 50 個 "="
print('='*50)
'''
with 語句
通常用在 資料庫讀取、檔案讀取或寫入、多線程
需要"釋放資源"的情況
'''

# 讀取檔案內容 - 常用的寫法 (執行完畢會自動關閉檔案)
with open(file='../module2/2-1.py', mode='r', encoding='utf-8') as f:
    doc = f.read()
print(doc)

# 印出 50 個 "="
print("="*50)
# Out:
# ==================================================
# # 建立第一支 Python 程式
#
# # 宣告變數
# x = 1
# name = "jia"
#
# # 輸出變數
# print(x)
# print(name)
#
#
# # CTRL + S 存檔
# # CTRL + / 註解程式碼
# # CTRL + ` 開啟終端機
# # CTRL + <num> 回到上方視窗
# # ctrl + z 上一動
# ==================================================

# %% [markdown]
# as 前面執行的內容存入as後面接的變數
# as e

# %%
# 一行一行讀取


with open(file='../module2/2-1.py', mode='r', encoding='utf-8') as f:
    doc_list= f.readlines()
    print(doc_list)
# Out:
# ['# 建立第一支 Python 程式\n', '\n', '# 宣告變數\n', 'x = 1\n', 'name = "jia" \n', '\n', '# 輸出變數\n', 'print(x)\n', 'print(name) \n', '\n', '\n', '# CTRL + S 存檔\n', '# CTRL + / 註解程式碼\n', '# CTRL + ` 開啟終端機\n', '# CTRL + <num> 回到上方視窗\n', '# ctrl + z 上一動']

# %%
# 資料處理
# 去除所有的 \n  
with open(file='../module2/2-1.py', mode='r', encoding='utf-8') as f:
    doc_list= f.readlines()
print(doc_list)

while '\n' in doc_list:
    doc_list.remove('\n')

print(doc_list)
new_list = []
for doc in doc_list:
    new_list.append(doc.strip('\n'))
    
print(new_list)
# Out:
# ['# 建立第一支 Python 程式\n', '\n', '# 宣告變數\n', 'x = 1\n', 'name = "jia" \n', '\n', '# 輸出變數\n', 'print(x)\n', 'print(name) \n', '\n', '\n', '# CTRL + S 存檔\n', '# CTRL + / 註解程式碼\n', '# CTRL + ` 開啟終端機\n', '# CTRL + <num> 回到上方視窗\n', '# ctrl + z 上一動']
# ['# 建立第一支 Python 程式\n', '# 宣告變數\n', 'x = 1\n', 'name = "jia" \n', '# 輸出變數\n', 'print(x)\n', 'print(name) \n', '# CTRL + S 存檔\n', '# CTRL + / 註解程式碼\n', '# CTRL + ` 開啟終端機\n', '# CTRL + <num> 回到上方視窗\n', '# ctrl + z 上一動']
# ['# 建立第一支 Python 程式', '# 宣告變數', 'x = 1', 'name = "jia" ', '# 輸出變數', 'print(x)', 'print(name) ', '# CTRL + S 存檔', '# CTRL + / 註解程式碼', '# CTRL + ` 開啟終端機', '# CTRL + <num> 回到上方視窗', '# ctrl + z 上一動']

# %% [markdown]
# ##### 寫入檔案 write( )

# %%
# 文字內容
text = '''
傑出的人會努力規劃自己的人生，普通的人則是隨便命運怎麼安排   
一個是充實、有目的的過每一天，一個是隨興的過一天算一天
創業這條路 Michael E.Gerber
'''

# 寫入檔案
with open(file= 'test.txt', mode= 'w', encoding='utf-8' ) as f:
    f.write(text)

# %%
# 寫入資料到最後一行 (附加文字在檔案內容最後一行)

msg=" People say that success just happens to you. It doesn't!"
with open(file= 'test.txt', mode= 'a', encoding='utf-8' ) as f:
    f.write(msg)
